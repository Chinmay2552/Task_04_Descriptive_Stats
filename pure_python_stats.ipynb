# %%
import csv
import math
from collections import defaultdict, Counter

def is_float(value):
    try:
        float(value)
        return True
    except:
        return False

# Load the data
data = []
with open('2024_fb_posts_president_scored_anon.csv', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        data.append(row)

# Get all column names
columns = data[0].keys()

# Initialize containers
numeric_stats = defaultdict(list)
non_numeric_stats = defaultdict(list)

# Classify and collect values
for row in data:
    for col, val in row.items():
        val = val.strip()
        if is_float(val):
            numeric_stats[col].append(float(val))
        else:
            non_numeric_stats[col].append(val)

# Compute numeric stats
for col, values in numeric_stats.items():
    count = len(values)
    mean = sum(values) / count
    min_val = min(values)
    max_val = max(values)
    std_dev = math.sqrt(sum((x - mean) ** 2 for x in values) / count)
    print(f"\nNumeric Column: {col}")
    print(f"  Count: {count}, Mean: {mean:.2f}, Min: {min_val}, Max: {max_val}, Std Dev: {std_dev:.2f}")

# Compute non-numeric stats
for col, values in non_numeric_stats.items():
    count = len(values)
    unique_vals = set(values)
    most_common = Counter(values).most_common(1)
    print(f"\nNon-numeric Column: {col}")
    print(f"  Count: {count}, Unique: {len(unique_vals)}, Most Frequent: {most_common}")
# Out:
# Numeric Column: Total Interactions
#   Count: 14398, Mean: 2210.15, Min: 0.0, Max: 470087.0, Std Dev: 13066.17
#
# Numeric Column: Likes
#   Count: 19009, Mean: 2377.70, Min: 0.0, Max: 351979.0, Std Dev: 11253.17
#
# Numeric Column: Comments
#   Count: 19009, Mean: 901.58, Min: 0.0, Max: 93872.0, Std Dev: 3681.88
#
# Numeric Column: Shares
#   Count: 19009, Mean: 320.54, Min: 0.0, Max: 76150.0, Std Dev: 1722.11
#
# Numeric Column: Love
#   Count: 19009, Mean: 413.88, Min: 0.0, Max: 244482.0, Std Dev: 3730.84
#
# Numeric Column: Wow
#   Count: 19009, Mean: 5.87, Min: 0.0, Max: 4345.0, Std Dev: 52.95
#
# Numeric Column: Haha
#   Count: 19009, Mean: 105.72, Min: 0.0, Max: 99276.0, Std Dev: 942.01
#
# Numeric Column: Sad
#   Count: 19009, Mean: 10.17, Min: 0.0, Max: 56111.0, Std Dev: 418.31
#
# Numeric Column: Angry
#   Count: 19009, Mean: 20.06, Min: 0.0, Max: 11814.0, Std Dev: 156.02
#
# Numeric Column: Care
#   Count: 19009, Mean: 34.93, Min: 0.0, Max: 85236.0, Std Dev: 790.08
#
# Numeric Column: Post Views
#   Count: 16544, Mean: 6485.06, Min: 0.0, Max: 4276477.0, Std Dev: 90390.23
#
# Numeric Column: Total Views
#   Count: 16544, Mean: 7461.85, Min: 0.0, Max: 4462155.0, Std Dev: 95973.38
#
# Numeric Column: Total Views For All Crossposts
#   Count: 16544, Mean: 3555.94, Min: 0.0, Max: 4499458.0, Std Dev: 88091.39
#
# Numeric Column: Overperforming Score
#   Count: 16544, Mean: -2.74, Min: -198.75, Max: 246.78, Std Dev: 7.81
#
# Numeric Column: advocacy_msg_type_illuminating
#   Count: 19009, Mean: 0.55, Min: 0.0, Max: 1.0, Std Dev: 0.50
#
# Numeric Column: issue_msg_type_illuminating
#   Count: 19009, Mean: 0.46, Min: 0.0, Max: 1.0, Std Dev: 0.50
#
# Numeric Column: attack_msg_type_illuminating
#   Count: 19009, Mean: 0.22, Min: 0.0, Max: 1.0, Std Dev: 0.41
#
# Numeric Column: image_msg_type_illuminating
#   Count: 19009, Mean: 0.15, Min: 0.0, Max: 1.0, Std Dev: 0.36
#
# Numeric Column: cta_msg_type_illuminating
#   Count: 19009, Mean: 0.13, Min: 0.0, Max: 1.0, Std Dev: 0.34
#
# Numeric Column: engagement_cta_subtype_illuminating
#   Count: 19009, Mean: 0.09, Min: 0.0, Max: 1.0, Std Dev: 0.29
#
# Numeric Column: fundraising_cta_subtype_illuminating
#   Count: 19009, Mean: 0.02, Min: 0.0, Max: 1.0, Std Dev: 0.13
#
# Numeric Column: voting_cta_subtype_illuminating
#   Count: 19009, Mean: 0.02, Min: 0.0, Max: 1.0, Std Dev: 0.15
#
# Numeric Column: covid_topic_illuminating
#   Count: 19009, Mean: 0.05, Min: 0.0, Max: 1.0, Std Dev: 0.22
#
# Numeric Column: economy_topic_illuminating
#   Count: 19009, Mean: 0.09, Min: 0.0, Max: 1.0, Std Dev: 0.29
#
# Numeric Column: education_topic_illuminating
#   Count: 19009, Mean: 0.01, Min: 0.0, Max: 1.0, Std Dev: 0.12
#
# Numeric Column: environment_topic_illuminating
#   Count: 19009, Mean: 0.02, Min: 0.0, Max: 1.0, Std Dev: 0.15
#
# Numeric Column: foreign_policy_topic_illuminating
#   Count: 19009, Mean: 0.04, Min: 0.0, Max: 1.0, Std Dev: 0.19
#
# Numeric Column: governance_topic_illuminating
#   Count: 19009, Mean: 0.03, Min: 0.0, Max: 1.0, Std Dev: 0.17
#
# Numeric Column: health_topic_illuminating
#   Count: 19009, Mean: 0.05, Min: 0.0, Max: 1.0, Std Dev: 0.22
#
# Numeric Column: immigration_topic_illuminating
#   Count: 19009, Mean: 0.04, Min: 0.0, Max: 1.0, Std Dev: 0.20
#
# Numeric Column: lgbtq_issues_topic_illuminating
#   Count: 19009, Mean: 0.00, Min: 0.0, Max: 1.0, Std Dev: 0.06
#
# Numeric Column: military_topic_illuminating
#   Count: 19009, Mean: 0.01, Min: 0.0, Max: 1.0, Std Dev: 0.07
#
# Numeric Column: race_and_ethnicity_topic_illuminating
#   Count: 19009, Mean: 0.02, Min: 0.0, Max: 1.0, Std Dev: 0.15
#
# Numeric Column: safety_topic_illuminating
#   Count: 19009, Mean: 0.03, Min: 0.0, Max: 1.0, Std Dev: 0.18
#
# Numeric Column: social_and_cultural_topic_illuminating
#   Count: 19009, Mean: 0.06, Min: 0.0, Max: 1.0, Std Dev: 0.24
#
# Numeric Column: technology_and_privacy_topic_illuminating
#   Count: 19009, Mean: 0.00, Min: 0.0, Max: 1.0, Std Dev: 0.05
#
# Numeric Column: womens_issue_topic_illuminating
#   Count: 19009, Mean: 0.03, Min: 0.0, Max: 1.0, Std Dev: 0.16
#
# Numeric Column: incivility_illuminating
#   Count: 19009, Mean: 0.13, Min: 0.0, Max: 1.0, Std Dev: 0.33
#
# Numeric Column: scam_illuminating
#   Count: 18060, Mean: 0.02, Min: 0.0, Max: 1.0, Std Dev: 0.14
#
# Numeric Column: freefair_illuminating
#   Count: 19009, Mean: 0.00, Min: 0.0, Max: 1.0, Std Dev: 0.05
#
# Numeric Column: fraud_illuminating
#   Count: 19009, Mean: 0.01, Min: 0.0, Max: 1.0, Std Dev: 0.09
#
# Non-numeric Column: Facebook_Id
#   Count: 19009, Unique: 21, Most Frequent: [('32fc18da91029ff09bf74fe9887eace6b5d2145809d583f696e344530508b064', 9013)]
#
# Non-numeric Column: post_id
#   Count: 19009, Unique: 19009, Most Frequent: [('8570b69695e00d8f06b12398ed525497e1712b5369c6fc2138fe98f69811c138', 1)]
#
# Non-numeric Column: Page Category
#   Count: 19009, Unique: 7, Most Frequent: [('PERSON', 9453)]
#
# Non-numeric Column: Page Admin Top Country
#   Count: 19009, Unique: 2, Most Frequent: [('US', 16280)]
#
# Non-numeric Column: Post Created
#   Count: 19009, Unique: 18951, Most Frequent: [('2023-11-14 11:11:44 EST', 2)]
#
# Non-numeric Column: Post Created Date
#   Count: 19009, Unique: 425, Most Frequent: [('2024-10-31', 103)]
#
# Non-numeric Column: Post Created Time
#   Count: 19009, Unique: 16102, Most Frequent: [('19:42:00', 7)]
#
# Non-numeric Column: Type
#   Count: 19009, Unique: 10, Most Frequent: [('Link', 7404)]
#
# Non-numeric Column: Video Share Status
#   Count: 19009, Unique: 4, Most Frequent: [('', 15738)]
#
# Non-numeric Column: Is Video Owner?
#   Count: 19009, Unique: 4, Most Frequent: [('-', 13280)]
#
# Non-numeric Column: Video Length
#   Count: 19009, Unique: 775, Most Frequent: [('', 15738)]
#
# Non-numeric Column: Sponsor Id
#   Count: 19009, Unique: 1, Most Frequent: [('', 19009)]
#
# Non-numeric Column: Sponsor Name
#   Count: 19009, Unique: 1, Most Frequent: [('', 19009)]
#
# Non-numeric Column: Sponsor Category
#   Count: 19009, Unique: 1, Most Frequent: [('', 19009)]
#
# Non-numeric Column: illuminating_scored_messageelection_integrity_Truth_illuminating
#   Count: 19009, Unique: 1, Most Frequent: [('', 19009)]
#
# Non-numeric Column: Total Interactions
#   Count: 4611, Unique: 3332, Most Frequent: [('1,139', 7)]
#
# Non-numeric Column: scam_illuminating
#   Count: 949, Unique: 1, Most Frequent: [('', 949)]
#
# Non-numeric Column: Post Views
#   Count: 2465, Unique: 1, Most Frequent: [('', 2465)]
#
# Non-numeric Column: Total Views
#   Count: 2465, Unique: 1, Most Frequent: [('', 2465)]
#
# Non-numeric Column: Total Views For All Crossposts
#   Count: 2465, Unique: 1, Most Frequent: [('', 2465)]
#
# Non-numeric Column: Overperforming Score
#   Count: 2465, Unique: 1, Most Frequent: [('', 2465)]

# %%
# Grouped by page_id
grouped_data = defaultdict(lambda: defaultdict(list))

for row in data:
    page = row.get("page_id", "").strip()
    for col, val in row.items():
        val = val.strip()
        if is_float(val):
            grouped_data[page][col].append(float(val))

# Compute stats per page_id
for page, columns in grouped_data.items():
    print(f"\n=== Stats for page_id: {page} ===")
    for col, values in columns.items():
        count = len(values)
        mean = sum(values) / count
        min_val = min(values)
        max_val = max(values)
        std_dev = math.sqrt(sum((x - mean) ** 2 for x in values) / count)
        print(f"  Column: {col}")
        print(f"    Count: {count}, Mean: {mean:.2f}, Min: {min_val}, Max: {max_val}, Std Dev: {std_dev:.2f}")
# Out:
# === Stats for page_id:  ===
#   Column: Total Interactions
#     Count: 14398, Mean: 2210.15, Min: 0.0, Max: 470087.0, Std Dev: 13066.17
#   Column: Likes
#     Count: 19009, Mean: 2377.70, Min: 0.0, Max: 351979.0, Std Dev: 11253.17
#   Column: Comments
#     Count: 19009, Mean: 901.58, Min: 0.0, Max: 93872.0, Std Dev: 3681.88
#   Column: Shares
#     Count: 19009, Mean: 320.54, Min: 0.0, Max: 76150.0, Std Dev: 1722.11
#   Column: Love
#     Count: 19009, Mean: 413.88, Min: 0.0, Max: 244482.0, Std Dev: 3730.84
#   Column: Wow
#     Count: 19009, Mean: 5.87, Min: 0.0, Max: 4345.0, Std Dev: 52.95
#   Column: Haha
#     Count: 19009, Mean: 105.72, Min: 0.0, Max: 99276.0, Std Dev: 942.01
#   Column: Sad
#     Count: 19009, Mean: 10.17, Min: 0.0, Max: 56111.0, Std Dev: 418.31
#   Column: Angry
#     Count: 19009, Mean: 20.06, Min: 0.0, Max: 11814.0, Std Dev: 156.02
#   Column: Care
#     Count: 19009, Mean: 34.93, Min: 0.0, Max: 85236.0, Std Dev: 790.08
#   Column: Post Views
#     Count: 16544, Mean: 6485.06, Min: 0.0, Max: 4276477.0, Std Dev: 90390.23
#   Column: Total Views
#     Count: 16544, Mean: 7461.85, Min: 0.0, Max: 4462155.0, Std Dev: 95973.38
#   Column: Total Views For All Crossposts
#     Count: 16544, Mean: 3555.94, Min: 0.0, Max: 4499458.0, Std Dev: 88091.39
#   Column: Overperforming Score
#     Count: 16544, Mean: -2.74, Min: -198.75, Max: 246.78, Std Dev: 7.81
#   Column: advocacy_msg_type_illuminating
#     Count: 19009, Mean: 0.55, Min: 0.0, Max: 1.0, Std Dev: 0.50
#   Column: issue_msg_type_illuminating
#     Count: 19009, Mean: 0.46, Min: 0.0, Max: 1.0, Std Dev: 0.50
#   Column: attack_msg_type_illuminating
#     Count: 19009, Mean: 0.22, Min: 0.0, Max: 1.0, Std Dev: 0.41
#   Column: image_msg_type_illuminating
#     Count: 19009, Mean: 0.15, Min: 0.0, Max: 1.0, Std Dev: 0.36
#   Column: cta_msg_type_illuminating
#     Count: 19009, Mean: 0.13, Min: 0.0, Max: 1.0, Std Dev: 0.34
#   Column: engagement_cta_subtype_illuminating
#     Count: 19009, Mean: 0.09, Min: 0.0, Max: 1.0, Std Dev: 0.29
#   Column: fundraising_cta_subtype_illuminating
#     Count: 19009, Mean: 0.02, Min: 0.0, Max: 1.0, Std Dev: 0.13
#   Column: voting_cta_subtype_illuminating
#     Count: 19009, Mean: 0.02, Min: 0.0, Max: 1.0, Std Dev: 0.15
#   Column: covid_topic_illuminating
#     Count: 19009, Mean: 0.05, Min: 0.0, Max: 1.0, Std Dev: 0.22
#   Column: economy_topic_illuminating
#     Count: 19009, Mean: 0.09, Min: 0.0, Max: 1.0, Std Dev: 0.29
#   Column: education_topic_illuminating
#     Count: 19009, Mean: 0.01, Min: 0.0, Max: 1.0, Std Dev: 0.12
#   Column: environment_topic_illuminating
#     Count: 19009, Mean: 0.02, Min: 0.0, Max: 1.0, Std Dev: 0.15
#   Column: foreign_policy_topic_illuminating
#     Count: 19009, Mean: 0.04, Min: 0.0, Max: 1.0, Std Dev: 0.19
#   Column: governance_topic_illuminating
#     Count: 19009, Mean: 0.03, Min: 0.0, Max: 1.0, Std Dev: 0.17
#   Column: health_topic_illuminating
#     Count: 19009, Mean: 0.05, Min: 0.0, Max: 1.0, Std Dev: 0.22
#   Column: immigration_topic_illuminating
#     Count: 19009, Mean: 0.04, Min: 0.0, Max: 1.0, Std Dev: 0.20
#   Column: lgbtq_issues_topic_illuminating
#     Count: 19009, Mean: 0.00, Min: 0.0, Max: 1.0, Std Dev: 0.06
#   Column: military_topic_illuminating
#     Count: 19009, Mean: 0.01, Min: 0.0, Max: 1.0, Std Dev: 0.07
#   Column: race_and_ethnicity_topic_illuminating
#     Count: 19009, Mean: 0.02, Min: 0.0, Max: 1.0, Std Dev: 0.15
#   Column: safety_topic_illuminating
#     Count: 19009, Mean: 0.03, Min: 0.0, Max: 1.0, Std Dev: 0.18
#   Column: social_and_cultural_topic_illuminating
#     Count: 19009, Mean: 0.06, Min: 0.0, Max: 1.0, Std Dev: 0.24
#   Column: technology_and_privacy_topic_illuminating
#     Count: 19009, Mean: 0.00, Min: 0.0, Max: 1.0, Std Dev: 0.05
#   Column: womens_issue_topic_illuminating
#     Count: 19009, Mean: 0.03, Min: 0.0, Max: 1.0, Std Dev: 0.16
#   Column: incivility_illuminating
#     Count: 19009, Mean: 0.13, Min: 0.0, Max: 1.0, Std Dev: 0.33
#   Column: scam_illuminating
#     Count: 18060, Mean: 0.02, Min: 0.0, Max: 1.0, Std Dev: 0.14
#   Column: freefair_illuminating
#     Count: 19009, Mean: 0.00, Min: 0.0, Max: 1.0, Std Dev: 0.05
#   Column: fraud_illuminating
#     Count: 19009, Mean: 0.01, Min: 0.0, Max: 1.0, Std Dev: 0.09

# %%
# Grouped by ad_id
grouped_data_pair = defaultdict(lambda: defaultdict(list))

for row in data:
    page = row.get("page_id", "").strip()
    ad = row.get("ad_id", "").strip()
    group_key = (page, ad)
    for col, val in row.items():
        val = val.strip()
        if is_float(val):
            grouped_data_pair[group_key][col].append(float(val))

# Compute stats per (page_id, ad_id)
for (page, ad), columns in grouped_data_pair.items():
    print(f"\n=== Stats for (page_id: {page}, ad_id: {ad}) ===")
    for col, values in columns.items():
        count = len(values)
        mean = sum(values) / count
        min_val = min(values)
        max_val = max(values)
        std_dev = math.sqrt(sum((x - mean) ** 2 for x in values) / count)
        print(f"  Column: {col}")
        print(f"    Count: {count}, Mean: {mean:.2f}, Min: {min_val}, Max: {max_val}, Std Dev: {std_dev:.2f}")
# Out:
# === Stats for (page_id: , ad_id: ) ===
#   Column: Total Interactions
#     Count: 14398, Mean: 2210.15, Min: 0.0, Max: 470087.0, Std Dev: 13066.17
#   Column: Likes
#     Count: 19009, Mean: 2377.70, Min: 0.0, Max: 351979.0, Std Dev: 11253.17
#   Column: Comments
#     Count: 19009, Mean: 901.58, Min: 0.0, Max: 93872.0, Std Dev: 3681.88
#   Column: Shares
#     Count: 19009, Mean: 320.54, Min: 0.0, Max: 76150.0, Std Dev: 1722.11
#   Column: Love
#     Count: 19009, Mean: 413.88, Min: 0.0, Max: 244482.0, Std Dev: 3730.84
#   Column: Wow
#     Count: 19009, Mean: 5.87, Min: 0.0, Max: 4345.0, Std Dev: 52.95
#   Column: Haha
#     Count: 19009, Mean: 105.72, Min: 0.0, Max: 99276.0, Std Dev: 942.01
#   Column: Sad
#     Count: 19009, Mean: 10.17, Min: 0.0, Max: 56111.0, Std Dev: 418.31
#   Column: Angry
#     Count: 19009, Mean: 20.06, Min: 0.0, Max: 11814.0, Std Dev: 156.02
#   Column: Care
#     Count: 19009, Mean: 34.93, Min: 0.0, Max: 85236.0, Std Dev: 790.08
#   Column: Post Views
#     Count: 16544, Mean: 6485.06, Min: 0.0, Max: 4276477.0, Std Dev: 90390.23
#   Column: Total Views
#     Count: 16544, Mean: 7461.85, Min: 0.0, Max: 4462155.0, Std Dev: 95973.38
#   Column: Total Views For All Crossposts
#     Count: 16544, Mean: 3555.94, Min: 0.0, Max: 4499458.0, Std Dev: 88091.39
#   Column: Overperforming Score
#     Count: 16544, Mean: -2.74, Min: -198.75, Max: 246.78, Std Dev: 7.81
#   Column: advocacy_msg_type_illuminating
#     Count: 19009, Mean: 0.55, Min: 0.0, Max: 1.0, Std Dev: 0.50
#   Column: issue_msg_type_illuminating
#     Count: 19009, Mean: 0.46, Min: 0.0, Max: 1.0, Std Dev: 0.50
#   Column: attack_msg_type_illuminating
#     Count: 19009, Mean: 0.22, Min: 0.0, Max: 1.0, Std Dev: 0.41
#   Column: image_msg_type_illuminating
#     Count: 19009, Mean: 0.15, Min: 0.0, Max: 1.0, Std Dev: 0.36
#   Column: cta_msg_type_illuminating
#     Count: 19009, Mean: 0.13, Min: 0.0, Max: 1.0, Std Dev: 0.34
#   Column: engagement_cta_subtype_illuminating
#     Count: 19009, Mean: 0.09, Min: 0.0, Max: 1.0, Std Dev: 0.29
#   Column: fundraising_cta_subtype_illuminating
#     Count: 19009, Mean: 0.02, Min: 0.0, Max: 1.0, Std Dev: 0.13
#   Column: voting_cta_subtype_illuminating
#     Count: 19009, Mean: 0.02, Min: 0.0, Max: 1.0, Std Dev: 0.15
#   Column: covid_topic_illuminating
#     Count: 19009, Mean: 0.05, Min: 0.0, Max: 1.0, Std Dev: 0.22
#   Column: economy_topic_illuminating
#     Count: 19009, Mean: 0.09, Min: 0.0, Max: 1.0, Std Dev: 0.29
#   Column: education_topic_illuminating
#     Count: 19009, Mean: 0.01, Min: 0.0, Max: 1.0, Std Dev: 0.12
#   Column: environment_topic_illuminating
#     Count: 19009, Mean: 0.02, Min: 0.0, Max: 1.0, Std Dev: 0.15
#   Column: foreign_policy_topic_illuminating
#     Count: 19009, Mean: 0.04, Min: 0.0, Max: 1.0, Std Dev: 0.19
#   Column: governance_topic_illuminating
#     Count: 19009, Mean: 0.03, Min: 0.0, Max: 1.0, Std Dev: 0.17
#   Column: health_topic_illuminating
#     Count: 19009, Mean: 0.05, Min: 0.0, Max: 1.0, Std Dev: 0.22
#   Column: immigration_topic_illuminating
#     Count: 19009, Mean: 0.04, Min: 0.0, Max: 1.0, Std Dev: 0.20
#   Column: lgbtq_issues_topic_illuminating
#     Count: 19009, Mean: 0.00, Min: 0.0, Max: 1.0, Std Dev: 0.06
#   Column: military_topic_illuminating
#     Count: 19009, Mean: 0.01, Min: 0.0, Max: 1.0, Std Dev: 0.07
#   Column: race_and_ethnicity_topic_illuminating
#     Count: 19009, Mean: 0.02, Min: 0.0, Max: 1.0, Std Dev: 0.15
#   Column: safety_topic_illuminating
#     Count: 19009, Mean: 0.03, Min: 0.0, Max: 1.0, Std Dev: 0.18
#   Column: social_and_cultural_topic_illuminating
#     Count: 19009, Mean: 0.06, Min: 0.0, Max: 1.0, Std Dev: 0.24
#   Column: technology_and_privacy_topic_illuminating
#     Count: 19009, Mean: 0.00, Min: 0.0, Max: 1.0, Std Dev: 0.05
#   Column: womens_issue_topic_illuminating
#     Count: 19009, Mean: 0.03, Min: 0.0, Max: 1.0, Std Dev: 0.16
#   Column: incivility_illuminating
#     Count: 19009, Mean: 0.13, Min: 0.0, Max: 1.0, Std Dev: 0.33
#   Column: scam_illuminating
#     Count: 18060, Mean: 0.02, Min: 0.0, Max: 1.0, Std Dev: 0.14
#   Column: freefair_illuminating
#     Count: 19009, Mean: 0.00, Min: 0.0, Max: 1.0, Std Dev: 0.05
#   Column: fraud_illuminating
#     Count: 19009, Mean: 0.01, Min: 0.0, Max: 1.0, Std Dev: 0.09
